# %% [markdown]
# # Analysis
#
# ---
#
# 1.	Based on the selected cities we can see that there is a positive significant correlation between Tem_Max and Latitude in the Southern hemisphere, so the closer we get to the Equator the warmer it gets. In the case of the Northern Hemisphere, we get an even stronger negative correlation. That is, the farther we get from the Equator the lower the temperature. This proves with data that temperatures at the Equator tend to be higher.
# 2.	Based on the selected cities, humidity seems to have some positive correlation as you get closer to the Equator in the Southern hemisphere. This is not the case though in the Northern hemisphere.
# 3.	For the rest of the parameters, there is no strong correlation for Cloudiness and Wind Speed relative to the Latitude of the selected cities.

# %% [markdown]
# # WeatherPy
# ----

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import math
import scipy.stats as sts


# Import API key
from config import wkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 594

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Create base DataFrame with the randomly generated list of cities
df = pd.DataFrame({'City':cities})

#Create needed columns to store data for each city
df['Lat'] =''
df['Lng'] =''
df['Max_Temp'] =''
df['Humidity'] =''
df['Cloudiness'] =''
df['Wind_Speed'] =''
df['Country'] =''
df['Date'] =''

#Perform API call to get information for each city
base_url = 'http://api.openweathermap.org/data/2.5/weather'

#Parameter for the API call, units will be handled in Metric system
params = {'appid':wkey, 'units':'metric'}

print('Begining Data Retireval')
print('--------------------------')

#Iterate through the list of cities to retrieve their information
for i, row in df.iterrows():
    
    params['q'] = row['City']
    city=row['City']
    print(f'Processing record {i} of {len(cities)-1} | {city}')
    
    response = requests.get(base_url,params=params).json()
    #Send to sleep to avoid reaching the 60rpm limit of the API
    time.sleep(1.5)
  
    try:
        df.loc[i,'Lat']= response['coord']['lat']
        df.loc[i,'Lng']= response['coord']['lon']
        df.loc[i,'Max_Temp']= response['main']['temp_max']
        df.loc[i,'Humidity']= response['main']['humidity']
        df.loc[i,'Cloudiness']= response['clouds']['all']
        df.loc[i,'Wind_Speed']= response['wind']['speed']
        df.loc[i,'Country']= response['sys']['country']
        df.loc[i,'Date']= response['dt']
    except:
        #Assign NaN to Cities not found to be dropped from the Dataframe
        df.loc[i,['Lat','Lng','Max_Temp','Humidity','Cloudiness','Wind_Speed','Country','Date']]= np.nan
        print('City not found. Skipping...')

#Drop cities which information was not found
df.dropna(inplace=True)
df.reset_index(inplace=True, drop=True)
print('--------------------------')
print('Data Retrieval Complete')
print('--------------------------')
# Out:
# Begining Data Retireval
# --------------------------
# Processing record 0 of 593 | bluff
# Processing record 1 of 593 | rikitea
# Processing record 2 of 593 | hobart
# Processing record 3 of 593 | taolanaro
# City not found. Skipping...
# Processing record 4 of 593 | punta arenas
# Processing record 5 of 593 | jamestown
# Processing record 6 of 593 | lorengau
# Processing record 7 of 593 | qaanaaq
# Processing record 8 of 593 | busselton
# Processing record 9 of 593 | srednekolymsk
# Processing record 10 of 593 | hermanus
# Processing record 11 of 593 | sexsmith
# Processing record 12 of 593 | barentsburg
# City not found. Skipping...
# Processing record 13 of 593 | carnarvon
# Processing record 14 of 593 | laguna
# Processing record 15 of 593 | cherskiy
# Processing record 16 of 593 | airai
# Processing record 17 of 593 | amderma
# City not found. Skipping...
# Processing record 18 of 593 | mitsamiouli
# Processing record 19 of 593 | ayan
# Processing record 20 of 593 | roma
# Processing record 21 of 593 | alotenango
# Processing record 22 of 593 | halifax
# Processing record 23 of 593 | tsihombe
# City not found. Skipping...
# Processing record 24 of 593 | kapaa
# Processing record 25 of 593 | bonavista
# Processing record 26 of 593 | tuktoyaktuk
# Processing record 27 of 593 | provideniya
# Processing record 28 of 593 | gizo
# Processing record 29 of 593 | bengkulu
# Processing record 30 of 593 | albany
# Processing record 31 of 593 | bredasdorp
# Processing record 32 of 593 | hilo
# Processing record 33 of 593 | bolshoye selo
# Processing record 34 of 593 | hasaki
# Processing record 35 of 593 | fairbanks
# Processing record 36 of 593 | khasan
# Processing record 37 of 593 | porto novo
# Processing record 38 of 593 | bilibino
# Processing record 39 of 593 | hofn
# Processing record 40 of 593 | vaini
# Processing record 41 of 593 | banda aceh
# Processing record 42 of 593 | mahebourg
# Processing record 43 of 593 | tadine
# Processing record 44 of 593 | hamilton
# Processing record 45 of 593 | puerto ayora
# Processing record 46 of 593 | ponta do sol
# Processing record 47 of 593 | flinders
# Processing record 48 of 593 | port elizabeth
# Processing record 49 of 593 | ushuaia
# Processing record 50 of 593 | fortuna
# Processing record 51 of 593 | nizhneyansk
# City not found. Skipping...
# Processing record 52 of 593 | vanavara
# Processing record 53 of 593 | port alfred
# Processing record 54 of 593 | barrow
# Processing record 55 of 593 | san vicente
# Processing record 56 of 593 | tawkar
# City not found. Skipping...
# Processing record 57 of 593 | manhattan
# Processing record 58 of 593 | plauen
# Processing record 59 of 593 | gubbi
# Processing record 60 of 593 | yellowknife
# Processing record 61 of 593 | belle fourche
# Processing record 62 of 593 | los llanos de aridane
# Processing record 63 of 593 | sibiti
# Processing record 64 of 593 | porbandar
# Processing record 65 of 593 | dikson
# Processing record 66 of 593 | east london
# Processing record 67 of 593 | sinfra
# Processing record 68 of 593 | santa rosalia
# Processing record 69 of 593 | tuatapere
# Processing record 70 of 593 | tlahualilo
# City not found. Skipping...
# Processing record 71 of 593 | hithadhoo
# Processing record 72 of 593 | butaritari
# Processing record 73 of 593 | pacific grove
# Processing record 74 of 593 | saskylakh
# Processing record 75 of 593 | inzer
# Processing record 76 of 593 | bure
# Processing record 77 of 593 | asbe teferi
# Processing record 78 of 593 | nambutalai
# Processing record 79 of 593 | kaitangata
# Processing record 80 of 593 | new norfolk
# Processing record 81 of 593 | clyde river
# Processing record 82 of 593 | faanui
# Processing record 83 of 593 | san patricio
# Processing record 84 of 593 | saint-philippe
# Processing record 85 of 593 | arraial do cabo
# Processing record 86 of 593 | nylstroom
# City not found. Skipping...
# Processing record 87 of 593 | tartus
# Processing record 88 of 593 | victor harbor
# Processing record 89 of 593 | hayrabolu
# Processing record 90 of 593 | madimba
# Processing record 91 of 593 | montgomery village
# Processing record 92 of 593 | mujiayingzi
# Processing record 93 of 593 | langxiang
# Processing record 94 of 593 | chuy
# Processing record 95 of 593 | longyearbyen
# Processing record 96 of 593 | gobabis
# Processing record 97 of 593 | mataura
# Processing record 98 of 593 | dhidhdhoo
# Processing record 99 of 593 | ancud
# Processing record 100 of 593 | mishkino
# Processing record 101 of 593 | capao da canoa
# Processing record 102 of 593 | saint-joseph
# Processing record 103 of 593 | hammerfest
# Processing record 104 of 593 | lebu
# Processing record 105 of 593 | boca do acre
# Processing record 106 of 593 | esperance
# Processing record 107 of 593 | amazar
# Processing record 108 of 593 | miles city
# Processing record 109 of 593 | kaoma
# Processing record 110 of 593 | chifeng
# Processing record 111 of 593 | tashara
# Processing record 112 of 593 | norman wells
# Processing record 113 of 593 | phalaborwa
# Processing record 114 of 593 | atuona
# Processing record 115 of 593 | grand river south east
# City not found. Skipping...
# Processing record 116 of 593 | la ferte-bernard
# Processing record 117 of 593 | port hedland
# Processing record 118 of 593 | tankhoy
# Processing record 119 of 593 | hualmay
# Processing record 120 of 593 | nikolskoye
# Processing record 121 of 593 | bend
# Processing record 122 of 593 | vardo
# Processing record 123 of 593 | qaqortoq
# Processing record 124 of 593 | malkara
# Processing record 125 of 593 | thompson
# Processing record 126 of 593 | cape town
# Processing record 127 of 593 | avarua
# Processing record 128 of 593 | kupang
# Processing record 129 of 593 | mirabad
# Processing record 130 of 593 | sogdiondon
# City not found. Skipping...
# Processing record 131 of 593 | mahajanga
# Processing record 132 of 593 | mys shmidta
# City not found. Skipping...
# Processing record 133 of 593 | cidreira
# Processing record 134 of 593 | pangnirtung
# Processing record 135 of 593 | rungata
# City not found. Skipping...
# Processing record 136 of 593 | lata
# Processing record 137 of 593 | visnes
# Processing record 138 of 593 | dunedin
# Processing record 139 of 593 | lagoa
# Processing record 140 of 593 | mount gambier
# Processing record 141 of 593 | sosnovo-ozerskoye
# Processing record 142 of 593 | san andres
# Processing record 143 of 593 | lubao
# Processing record 144 of 593 | hervey bay
# Processing record 145 of 593 | bethel
# Processing record 146 of 593 | kodiak
# Processing record 147 of 593 | khatanga
# Processing record 148 of 593 | tornio
# Processing record 149 of 593 | dumbravita
# Processing record 150 of 593 | bambous virieux
# Processing record 151 of 593 | rio gallegos
# Processing record 152 of 593 | portland
# Processing record 153 of 593 | haines junction
# Processing record 154 of 593 | puerto gaitan
# Processing record 155 of 593 | georgetown
# Processing record 156 of 593 | ngukurr
# City not found. Skipping...
# Processing record 157 of 593 | vao
# Processing record 158 of 593 | riyadh
# Processing record 159 of 593 | coahuayana
# Processing record 160 of 593 | banikoara
# Processing record 161 of 593 | barranca
# Processing record 162 of 593 | izhma
# Processing record 163 of 593 | erdemli
# Processing record 164 of 593 | ola
# Processing record 165 of 593 | hauterive
# Processing record 166 of 593 | khilok
# Processing record 167 of 593 | victoria
# Processing record 168 of 593 | alugan
# Processing record 169 of 593 | geraldton
# Processing record 170 of 593 | severo-kurilsk
# Processing record 171 of 593 | kapoeta
# Processing record 172 of 593 | daru
# Processing record 173 of 593 | pevek
# Processing record 174 of 593 | yaan
# Processing record 175 of 593 | tumannyy
# City not found. Skipping...
# Processing record 176 of 593 | guozhen
# Processing record 177 of 593 | tromso
# Processing record 178 of 593 | san cristobal
# Processing record 179 of 593 | ribeira grande
# Processing record 180 of 593 | codrington
# Processing record 181 of 593 | coquimbo
# Processing record 182 of 593 | salalah
# Processing record 183 of 593 | manzanillo
# Processing record 184 of 593 | soyo
# Processing record 185 of 593 | neon soulion
# Processing record 186 of 593 | santa rosa de viterbo
# Processing record 187 of 593 | port lincoln
# Processing record 188 of 593 | nemuro
# Processing record 189 of 593 | moindou
# Processing record 190 of 593 | richards bay
# Processing record 191 of 593 | erzin
# Processing record 192 of 593 | sao filipe
# Processing record 193 of 593 | meulaboh
# Processing record 194 of 593 | pemberton
# Processing record 195 of 593 | lazaro cardenas
# Processing record 196 of 593 | caravelas
# Processing record 197 of 593 | baton rouge
# Processing record 198 of 593 | khonuu
# City not found. Skipping...
# Processing record 199 of 593 | kharp
# Processing record 200 of 593 | port macquarie
# Processing record 201 of 593 | taoudenni
# Processing record 202 of 593 | seoul
# Processing record 203 of 593 | cookeville
# Processing record 204 of 593 | touros
# Processing record 205 of 593 | ulladulla
# Processing record 206 of 593 | mersing
# Processing record 207 of 593 | atambua
# Processing record 208 of 593 | kijang
# Processing record 209 of 593 | kirando
# Processing record 210 of 593 | chimbote
# Processing record 211 of 593 | alexandria
# Processing record 212 of 593 | port-gentil
# Processing record 213 of 593 | clones
# Processing record 214 of 593 | galle
# Processing record 215 of 593 | carcassonne
# Processing record 216 of 593 | chokurdakh
# Processing record 217 of 593 | cayenne
# Processing record 218 of 593 | tupelo
# Processing record 219 of 593 | beringovskiy
# Processing record 220 of 593 | iqaluit
# Processing record 221 of 593 | smithers
# Processing record 222 of 593 | saint george
# Processing record 223 of 593 | barabash
# Processing record 224 of 593 | karachi
# Processing record 225 of 593 | port moresby
# Processing record 226 of 593 | miranorte
# City not found. Skipping...
# Processing record 227 of 593 | pangai
# Processing record 228 of 593 | kambove
# Processing record 229 of 593 | mao
# Processing record 230 of 593 | balabac
# Processing record 231 of 593 | coihaique
# Processing record 232 of 593 | klaksvik
# Processing record 233 of 593 | luanda
# Processing record 234 of 593 | fereydunshahr
# Processing record 235 of 593 | careiro da varzea
# Processing record 236 of 593 | jalu
# Processing record 237 of 593 | krasnoselkup
# Processing record 238 of 593 | sinnamary
# Processing record 239 of 593 | aripuana
# Processing record 240 of 593 | vila franca do campo
# Processing record 241 of 593 | namibe
# Processing record 242 of 593 | svetlogorsk
# Processing record 243 of 593 | illoqqortoormiut
# City not found. Skipping...
# Processing record 244 of 593 | lisa
# Processing record 245 of 593 | kavieng
# Processing record 246 of 593 | the valley
# Processing record 247 of 593 | winslow
# Processing record 248 of 593 | thunder bay
# Processing record 249 of 593 | sorland
# Processing record 250 of 593 | berlevag
# Processing record 251 of 593 | phuthaditjhaba
# Processing record 252 of 593 | weihai
# Processing record 253 of 593 | dingle
# Processing record 254 of 593 | praia da vitoria
# Processing record 255 of 593 | pedana
# Processing record 256 of 593 | bin qirdan
# Processing record 257 of 593 | alyangula
# Processing record 258 of 593 | ozu
# Processing record 259 of 593 | mercedes
# Processing record 260 of 593 | rocha
# Processing record 261 of 593 | zyryanka
# Processing record 262 of 593 | marienburg
# Processing record 263 of 593 | goderich
# Processing record 264 of 593 | tasiilaq
# Processing record 265 of 593 | saint-francois
# Processing record 266 of 593 | ilulissat
# Processing record 267 of 593 | zhuhai
# Processing record 268 of 593 | samusu
# City not found. Skipping...
# Processing record 269 of 593 | beaverton
# Processing record 270 of 593 | ergani
# Processing record 271 of 593 | jabiru
# City not found. Skipping...
# Processing record 272 of 593 | lavrentiya
# Processing record 273 of 593 | naze
# Processing record 274 of 593 | iberia
# Processing record 275 of 593 | avera
# Processing record 276 of 593 | severodvinsk
# Processing record 277 of 593 | pisco
# Processing record 278 of 593 | kilinochchi
# Processing record 279 of 593 | nanortalik
# Processing record 280 of 593 | devonport
# Processing record 281 of 593 | severobaykalsk
# Processing record 282 of 593 | hay river
# Processing record 283 of 593 | sept-iles
# Processing record 284 of 593 | kununurra
# Processing record 285 of 593 | upernavik
# Processing record 286 of 593 | kulpahar
# Processing record 287 of 593 | jumla
# Processing record 288 of 593 | ayolas
# Processing record 289 of 593 | ariquemes
# Processing record 290 of 593 | mareeba
# Processing record 291 of 593 | leningradskiy
# Processing record 292 of 593 | correntina
# Processing record 293 of 593 | sungairaya
# Processing record 294 of 593 | kurilsk
# Processing record 295 of 593 | koumac
# Processing record 296 of 593 | puerto madero
# Processing record 297 of 593 | mata de sao joao
# Processing record 298 of 593 | carroll
# Processing record 299 of 593 | dongsheng
# Processing record 300 of 593 | tiksi
# Processing record 301 of 593 | three hills
# Processing record 302 of 593 | dudhani
# Processing record 303 of 593 | komsomolskiy
# Processing record 304 of 593 | cabo san lucas
# Processing record 305 of 593 | ushtobe
# Processing record 306 of 593 | guerrero negro
# Processing record 307 of 593 | grindavik
# Processing record 308 of 593 | yar-sale
# Processing record 309 of 593 | taltal
# Processing record 310 of 593 | san ignacio de sabaneta
# City not found. Skipping...
# Processing record 311 of 593 | gat
# Processing record 312 of 593 | bandarbeyla
# Processing record 313 of 593 | thinadhoo
# Processing record 314 of 593 | acarau
# Processing record 315 of 593 | belushya guba
# City not found. Skipping...
# Processing record 316 of 593 | tecozautla
# Processing record 317 of 593 | rabo de peixe
# Processing record 318 of 593 | tautira
# Processing record 319 of 593 | la ronge
# Processing record 320 of 593 | kudahuvadhoo
# Processing record 321 of 593 | tokur
# Processing record 322 of 593 | podosinovets
# Processing record 323 of 593 | padang
# Processing record 324 of 593 | chicama
# Processing record 325 of 593 | tual
# Processing record 326 of 593 | mitu
# Processing record 327 of 593 | ixtapa
# Processing record 328 of 593 | rovaniemi
# Processing record 329 of 593 | vestmannaeyjar
# Processing record 330 of 593 | gunjur
# Processing record 331 of 593 | yerbogachen
# Processing record 332 of 593 | borogontsy
# Processing record 333 of 593 | torbay
# Processing record 334 of 593 | ewa beach
# Processing record 335 of 593 | kawana waters
# City not found. Skipping...
# Processing record 336 of 593 | aden
# Processing record 337 of 593 | sterling
# Processing record 338 of 593 | nurota
# Processing record 339 of 593 | palabuhanratu
# City not found. Skipping...
# Processing record 340 of 593 | upata
# Processing record 341 of 593 | san quintin
# Processing record 342 of 593 | viligili
# City not found. Skipping...
# Processing record 343 of 593 | crib point
# Processing record 344 of 593 | mogadishu
# Processing record 345 of 593 | basco
# Processing record 346 of 593 | fort saint john
# City not found. Skipping...
# Processing record 347 of 593 | yumen
# Processing record 348 of 593 | kahului
# Processing record 349 of 593 | fort collins
# Processing record 350 of 593 | pangody
# Processing record 351 of 593 | abu zabad
# Processing record 352 of 593 | belaya gora
# Processing record 353 of 593 | orotukan
# Processing record 354 of 593 | rawson
# Processing record 355 of 593 | arucas
# Processing record 356 of 593 | chunskiy
# Processing record 357 of 593 | yian
# City not found. Skipping...
# Processing record 358 of 593 | deputatskiy
# Processing record 359 of 593 | manggar
# Processing record 360 of 593 | turukhansk
# Processing record 361 of 593 | moba
# Processing record 362 of 593 | svetlyy
# Processing record 363 of 593 | hami
# Processing record 364 of 593 | tahoua
# Processing record 365 of 593 | nishihara
# Processing record 366 of 593 | saint anthony
# Processing record 367 of 593 | boa vista
# Processing record 368 of 593 | casas adobes
# Processing record 369 of 593 | changji
# Processing record 370 of 593 | ormara
# Processing record 371 of 593 | matara
# Processing record 372 of 593 | flin flon
# Processing record 373 of 593 | saleaula
# City not found. Skipping...
# Processing record 374 of 593 | evensk
# Processing record 375 of 593 | mangrol
# Processing record 376 of 593 | marsh harbour
# Processing record 377 of 593 | joniskis
# Processing record 378 of 593 | akyab
# Processing record 379 of 593 | ust-nera
# Processing record 380 of 593 | tete
# Processing record 381 of 593 | taksimo
# Processing record 382 of 593 | milkovo
# Processing record 383 of 593 | goundam
# Processing record 384 of 593 | bilma
# Processing record 385 of 593 | san matias
# Processing record 386 of 593 | bereznik
# Processing record 387 of 593 | puerto colombia
# Processing record 388 of 593 | xiongshi
# City not found. Skipping...
# Processing record 389 of 593 | tezu
# Processing record 390 of 593 | namatanai
# Processing record 391 of 593 | iquitos
# Processing record 392 of 593 | sioux lookout
# Processing record 393 of 593 | we
# City not found. Skipping...
# Processing record 394 of 593 | sarangani
# Processing record 395 of 593 | ngunguru
# Processing record 396 of 593 | marawi
# Processing record 397 of 593 | wahiawa
# Processing record 398 of 593 | luderitz
# Processing record 399 of 593 | port arthur
# Processing record 400 of 593 | borba
# Processing record 401 of 593 | lucea
# Processing record 402 of 593 | bolungarvik
# City not found. Skipping...
# Processing record 403 of 593 | kommunisticheskiy
# Processing record 404 of 593 | ko samui
# Processing record 405 of 593 | plouzane
# Processing record 406 of 593 | saldanha
# Processing record 407 of 593 | kaduqli
# Processing record 408 of 593 | tomatlan
# Processing record 409 of 593 | guilin
# Processing record 410 of 593 | lasa
# Processing record 411 of 593 | solovetskiy
# City not found. Skipping...
# Processing record 412 of 593 | orgtrud
# Processing record 413 of 593 | kiruna
# Processing record 414 of 593 | najran
# Processing record 415 of 593 | vanimo
# Processing record 416 of 593 | cap malheureux
# Processing record 417 of 593 | bandar-e torkaman
# City not found. Skipping...
# Processing record 418 of 593 | coronado
# Processing record 419 of 593 | port hardy
# Processing record 420 of 593 | roros
# Processing record 421 of 593 | santander
# Processing record 422 of 593 | kazalinsk
# City not found. Skipping...
# Processing record 423 of 593 | bismarck
# Processing record 424 of 593 | kadoma
# Processing record 425 of 593 | pakala
# Processing record 426 of 593 | el tigre
# Processing record 427 of 593 | palmer
# Processing record 428 of 593 | kokoda
# Processing record 429 of 593 | banepa
# Processing record 430 of 593 | north bend
# Processing record 431 of 593 | katsuura
# Processing record 432 of 593 | igarka
# Processing record 433 of 593 | umzimvubu
# City not found. Skipping...
# Processing record 434 of 593 | tahta
# Processing record 435 of 593 | lolua
# City not found. Skipping...
# Processing record 436 of 593 | melilla
# Processing record 437 of 593 | whitefish
# Processing record 438 of 593 | atar
# Processing record 439 of 593 | yarada
# Processing record 440 of 593 | ipeti
# City not found. Skipping...
# Processing record 441 of 593 | sandpoint
# Processing record 442 of 593 | zhanaozen
# Processing record 443 of 593 | college
# Processing record 444 of 593 | jomalig
# City not found. Skipping...
# Processing record 445 of 593 | zhigansk
# Processing record 446 of 593 | toyooka
# Processing record 447 of 593 | tamiahua
# Processing record 448 of 593 | souillac
# Processing record 449 of 593 | cherkasskoye
# Processing record 450 of 593 | kailua
# Processing record 451 of 593 | pochutla
# Processing record 452 of 593 | zalari
# Processing record 453 of 593 | ust-kamchatsk
# City not found. Skipping...
# Processing record 454 of 593 | castro
# Processing record 455 of 593 | anadyr
# Processing record 456 of 593 | whitehorse
# Processing record 457 of 593 | kamina
# Processing record 458 of 593 | shelburne
# Processing record 459 of 593 | baoshan
# Processing record 460 of 593 | lalin
# Processing record 461 of 593 | constitucion
# Processing record 462 of 593 | zlobin
# Processing record 463 of 593 | schattdorf
# Processing record 464 of 593 | kruisfontein
# Processing record 465 of 593 | xinzhou
# Processing record 466 of 593 | cadiz
# Processing record 467 of 593 | inuvik
# Processing record 468 of 593 | iregszemcse
# Processing record 469 of 593 | severo-yeniseyskiy
# Processing record 470 of 593 | haapiti
# Processing record 471 of 593 | monrovia
# Processing record 472 of 593 | sihora
# Processing record 473 of 593 | palestine
# Processing record 474 of 593 | handan
# Processing record 475 of 593 | rafaela
# Processing record 476 of 593 | ajaccio
# Processing record 477 of 593 | ashqelon
# Processing record 478 of 593 | noshiro
# Processing record 479 of 593 | chadiza
# Processing record 480 of 593 | methoni
# Processing record 481 of 593 | opuwo
# Processing record 482 of 593 | esna
# Processing record 483 of 593 | puri
# Processing record 484 of 593 | mbandaka
# Processing record 485 of 593 | weligama
# Processing record 486 of 593 | narsaq
# Processing record 487 of 593 | portobelo
# Processing record 488 of 593 | petropavlovka
# Processing record 489 of 593 | great bend
# Processing record 490 of 593 | rio tercero
# Processing record 491 of 593 | ada
# Processing record 492 of 593 | morgantown
# Processing record 493 of 593 | nuuk
# Processing record 494 of 593 | verkh-usugli
# Processing record 495 of 593 | santa maria
# Processing record 496 of 593 | ryotsu
# Processing record 497 of 593 | mar del plata
# Processing record 498 of 593 | kidal
# Processing record 499 of 593 | broome
# Processing record 500 of 593 | hakvik
# City not found. Skipping...
# Processing record 501 of 593 | muchkapskiy
# Processing record 502 of 593 | santa cruz de tenerife
# Processing record 503 of 593 | elko
# Processing record 504 of 593 | oyon
# Processing record 505 of 593 | aklavik
# Processing record 506 of 593 | vzmorye
# Processing record 507 of 593 | sao gabriel da cachoeira
# Processing record 508 of 593 | havelock
# Processing record 509 of 593 | mana
# Processing record 510 of 593 | xiaolan
# Processing record 511 of 593 | jinchengjiang
# City not found. Skipping...
# Processing record 512 of 593 | batagay-alyta
# Processing record 513 of 593 | kosikha
# Processing record 514 of 593 | isla mujeres
# Processing record 515 of 593 | bubaque
# Processing record 516 of 593 | vagur
# Processing record 517 of 593 | mingaora
# Processing record 518 of 593 | agadez
# Processing record 519 of 593 | quatre cocos
# Processing record 520 of 593 | antofagasta
# Processing record 521 of 593 | jubb jannin
# City not found. Skipping...
# Processing record 522 of 593 | ondorhaan
# City not found. Skipping...
# Processing record 523 of 593 | saint-leu
# Processing record 524 of 593 | sayyan
# Processing record 525 of 593 | pundaguitan
# Processing record 526 of 593 | sola
# Processing record 527 of 593 | surgut
# Processing record 528 of 593 | norden
# Processing record 529 of 593 | tommot
# Processing record 530 of 593 | kargil
# Processing record 531 of 593 | attawapiskat
# City not found. Skipping...
# Processing record 532 of 593 | vila
# Processing record 533 of 593 | aksha
# Processing record 534 of 593 | cumberland
# Processing record 535 of 593 | paamiut
# Processing record 536 of 593 | char bhadrasan
# Processing record 537 of 593 | ahipara
# Processing record 538 of 593 | kavaratti
# Processing record 539 of 593 | altay
# Processing record 540 of 593 | hameenlinna
# Processing record 541 of 593 | oranjemund
# Processing record 542 of 593 | nargana
# Processing record 543 of 593 | ifanadiana
# Processing record 544 of 593 | toungoo
# City not found. Skipping...
# Processing record 545 of 593 | ipixuna
# Processing record 546 of 593 | kasulu
# Processing record 547 of 593 | tucumcari
# Processing record 548 of 593 | algeciras
# Processing record 549 of 593 | djibo
# Processing record 550 of 593 | am timan
# Processing record 551 of 593 | sinegorye
# Processing record 552 of 593 | marcona
# City not found. Skipping...
# Processing record 553 of 593 | inhambane
# Processing record 554 of 593 | khandyga
# Processing record 555 of 593 | preobrazheniye
# Processing record 556 of 593 | shaoyang
# Processing record 557 of 593 | nhulunbuy
# Processing record 558 of 593 | olinda
# Processing record 559 of 593 | harper
# Processing record 560 of 593 | filadelfia
# Processing record 561 of 593 | husavik
# Processing record 562 of 593 | alihe
# Processing record 563 of 593 | gurskoye
# City not found. Skipping...
# Processing record 564 of 593 | petropavlovsk-kamchatskiy
# Processing record 565 of 593 | sokoto
# Processing record 566 of 593 | santa isabel do rio negro
# Processing record 567 of 593 | nome
# Processing record 568 of 593 | cockburn town
# Processing record 569 of 593 | etchoropo
# Processing record 570 of 593 | puerto escondido
# Processing record 571 of 593 | tessalit
# Processing record 572 of 593 | sovetskiy
# Processing record 573 of 593 | ujhartyan
# Processing record 574 of 593 | bolo
# Processing record 575 of 593 | talnakh
# Processing record 576 of 593 | freehold
# Processing record 577 of 593 | havoysund
# Processing record 578 of 593 | walvis bay
# Processing record 579 of 593 | groton
# Processing record 580 of 593 | dodoma
# Processing record 581 of 593 | that phanom
# Processing record 582 of 593 | puro
# Processing record 583 of 593 | torbeyevo
# Processing record 584 of 593 | kingseat
# Processing record 585 of 593 | katobu
# Processing record 586 of 593 | chai badan
# Processing record 587 of 593 | kamenka
# Processing record 588 of 593 | ajdabiya
# Processing record 589 of 593 | anar darreh
# City not found. Skipping...
# Processing record 590 of 593 | byron bay
# Processing record 591 of 593 | bathsheba
# Processing record 592 of 593 | santa cruz
# Processing record 593 of 593 | christchurch
# --------------------------
# Data Retrieval Complete
# --------------------------

# %%
#Reset Index and analyze Dataframe
df.head()
# Out:
#            City      Lat      Lng Max_Temp Humidity Cloudiness Wind_Speed  \
# 0         bluff    -46.6  168.333    13.86       61          0      10.13
# 1       rikitea -23.1203 -134.969    25.53       72          1       6.21
# 2        hobart -42.8794  147.329    22.78       64         20       3.09
# 3  punta arenas   -53.15 -70.9167       15       77          0       6.17
# 4     jamestown   42.097 -79.2353    -5.56       93          1       4.63
#
#   Country        Date
# 0      NZ  1612405408
# 1      PF  1612405648
# 2      AU  1612405649
# 3      CL  1612405653
# 4      US  1612405415

# %%
#Save DataFrame to .csv file
df.to_csv(output_data_file, index=False)

# %%
#inspect the Dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        547 non-null    object
#  1   Lat         547 non-null    object
#  2   Lng         547 non-null    object
#  3   Max_Temp    547 non-null    object
#  4   Humidity    547 non-null    object
#  5   Cloudiness  547 non-null    object
#  6   Wind_Speed  547 non-null    object
#  7   Country     547 non-null    object
#  8   Date        547 non-null    object
# dtypes: object(9)
# memory usage: 38.6+ KB

# %%
#Fix Data types for numerical columns
df[['Lat','Lng','Max_Temp','Humidity','Cloudiness','Wind_Speed','Date']]=df[['Lat','Lng','Max_Temp','Humidity','Cloudiness','Wind_Speed','Date']].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        547 non-null    object
#  1   Lat         547 non-null    float64
#  2   Lng         547 non-null    float64
#  3   Max_Temp    547 non-null    float64
#  4   Humidity    547 non-null    float64
#  5   Cloudiness  547 non-null    float64
#  6   Wind_Speed  547 non-null    float64
#  7   Country     547 non-null    object
#  8   Date        547 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 38.6+ KB

# %%
df.describe()
# Out:
#               Lat         Lng    Max_Temp    Humidity  Cloudiness  Wind_Speed  \
# count  547.000000  547.000000  547.000000  547.000000  547.000000  547.000000
# mean    22.366098   18.034444    8.674461   74.809872   50.839122    3.923473
# std     32.828425   92.461773   17.822371   18.834260   40.214531    2.941834
# min    -54.800000 -175.200000  -42.730000   12.000000    0.000000    0.210000
# 25%     -3.674300  -66.047300   -2.000000   66.500000    2.000000    1.540000
# 50%     27.629800   23.650000   15.000000   78.000000   46.000000    3.090000
# 75%     48.405600  102.272600   23.270000   88.000000   90.000000    5.305000
# max     78.218600  179.316700   32.030000  100.000000  100.000000   17.000000
#
#                Date
# count  5.470000e+02
# mean   1.612406e+09
# std    2.893243e+02
# min    1.612405e+09
# 25%    1.612406e+09
# 50%    1.612406e+09
# 75%    1.612406e+09
# max    1.612407e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#No Cities in the Dataset have Humidity >100, skipping this step
df.loc[df['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max_Temp, Humidity, Cloudiness, Wind_Speed, Country, Date]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['Lat'],df['Max_Temp'], alpha=0.5)
plt.title('City Latitud vs Max Temperature (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.vlines(0,-60,60, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(-50,40)
plt.legend()
plt.grid()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['Lat'],df['Humidity'], alpha=0.5)
plt.title('City Latitude vs Humidity (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.vlines(0,0,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,110)
plt.legend()
plt.grid()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['Lat'],df['Cloudiness'], alpha=0.5)
plt.title('City Latitude vs Cloudiness (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.vlines(0,-5,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(-5,110)
plt.legend()
plt.grid()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(12,6))
plt.scatter(df['Lat'],df['Wind_Speed'], alpha=0.5)
plt.title('City Latitude vs Wind Speed (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.vlines(0,-5,20, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,20)
plt.legend()
plt.grid()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x=df[df['Lat']>=0]['Lat']
y=df[df['Lat']>=0]['Max_Temp']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(6,-10), fontsize=20, color='mediumseagreen')
plt.title('Northern Hemisphere: City Latitude vs Max Temperature (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.vlines(0,-60,60, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(-50,40)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:-0.8866339702720367

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x=df[df['Lat']<0]['Lat']
y=df[df['Lat']<0]['Max_Temp']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(-45,30), fontsize=20, color='mediumseagreen')
plt.title('Southern Hemisphere: City Latitude vs Max Temperature (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.vlines(0,-60,60, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,40)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:0.48870369762760135

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x=df[df['Lat']>=0]['Lat']
y=df[df['Lat']>=0]['Humidity']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(55,40), fontsize=20, color='mediumseagreen')
plt.title('Northern Hemisphere: City Latitude vs Humidity (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.vlines(0,0,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,110)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:0.33367792711427097

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x=df[df['Lat']<0]['Lat']
y=df[df['Lat']<0]['Humidity']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(55,40), fontsize=20, color='mediumseagreen')
plt.title('Southern Hemisphere: City Latitude vs Humidity (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.vlines(0,0,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,110)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:0.3718270298893388

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x=df[df['Lat']>=0]['Lat']
y=df[df['Lat']>=0]['Cloudiness']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(55,40), fontsize=20, color='mediumseagreen')
plt.title('Northern Hemisphere: City Latitude vs Cloudiness (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.vlines(0,0,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,110)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:0.2573904364129935

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x=df[df['Lat']<0]['Lat']
y=df[df['Lat']<0]['Cloudiness']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(55,40), fontsize=20, color='mediumseagreen')
plt.title('Southern Hemisphere: City Latitude vs Cloudiness (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.vlines(0,0,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,110)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:0.3580123257718628

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x=df[df['Lat']>=0]['Lat']
y=df[df['Lat']>=0]['Wind_Speed']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(30,15), fontsize=20, color='mediumseagreen')
plt.title('Northern Hemisphere: City Latitude vs Wind Speed m/s (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed m/s')
plt.vlines(0,0,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,20)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:-0.016116187469476757

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x=df[df['Lat']<0]['Lat']
y=df[df['Lat']<0]['Wind_Speed']
plt.figure(figsize=(12,6))
plt.scatter(x,y, alpha=0.5)
(slope,intercept,rvalue,pvalue,stderr) = sts.linregress(x,y)
regress_line = x*slope+intercept
linear_eq = 'y = ' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.plot(x,regress_line, label ='Regression', c='mediumseagreen')
plt.annotate(linear_eq,(30,15), fontsize=20, color='mediumseagreen')
plt.title('Southern Hemisphere: City Latitude vs Wind Speed m/s (02/01/21)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed m/s')
plt.vlines(0,0,110, linestyles='dashed', label ='Equator', colors='r')
plt.ylim(0,20)
plt.legend()
plt.grid()
print(f'The r-value is:{sts.pearsonr(x,y)[0]}')
plt.show()
# Out:
# The r-value is:-0.2802358767554035
